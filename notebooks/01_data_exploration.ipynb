# %%
import pandas as pd
import json
from pathlib import Path

# %%
def parse_wpl_json(file_path):
    with open(file_path, 'r') as f:
        data = json.load(f)
    
    # Extract metadata from the 'info' section
    match_id = os.path.basename(file_path).split('.')[0]
    city = data['info'].get('city', 'Unknown')
    date = data['info']['dates'][0]
    
    ball_data = []
    
    for inning_num, inning in enumerate(data['innings']):
        team_batting = inning['team']
        # Find who the bowling team is
        teams = data['info']['teams']
        team_bowling = [t for t in teams if t != team_batting][0]
        
        for over_data in inning['overs']:
            over_num = over_data['over']
            
            for ball_num, delivery in enumerate(over_data['deliveries']):
                # Basic info
                record = {
                    'match_id': match_id,
                    'date': date,
                    'inning': inning_num + 1,
                    'batting_team': team_batting,
                    'bowling_team': team_bowling,
                    'over': over_num,
                    'ball': ball_num + 1,
                    'batter': delivery['batter'],
                    'bowler': delivery['bowler'],
                    'non_striker': delivery['non_striker'],
                    'runs_bat': delivery['runs']['batter'],
                    'runs_extras': delivery['runs']['extras'],
                    'runs_total': delivery['runs']['total']
                }
                
                # Check for Wides/No Balls (important for balls faced/bowled)
                if 'extras' in delivery:
                    record['is_wide'] = 1 if 'wides' in delivery['extras'] else 0
                    record['is_noball'] = 1 if 'noballs' in delivery['extras'] else 0
                else:
                    record['is_wide'] = 0
                    record['is_noball'] = 0
                
                # Check for Wickets
                if 'wickets' in delivery:
                    record['is_wicket'] = 1
                    record['player_out'] = delivery['wickets'][0]['player_out']
                    record['wicket_kind'] = delivery['wickets'][0]['kind']
                else:
                    record['is_wicket'] = 0
                    record['player_out'] = None
                    record['wicket_kind'] = None
                
                ball_data.append(record)
                
    return pd.DataFrame(ball_data)

# %%
base_path = Path.cwd().parent
data_folder = base_path / 'Data' / '01_raw_data' / 'wpl_json'

# 2. List to store dataframes (faster than appending to a df in a loop)
dfs_list = []

if data_folder.exists() and data_folder.is_dir():
    print('Reading data from:', data_folder)

    # 3. Iterate through files
    for file_path in data_folder.glob('*.json'): # Added .json to be specific
        try:
            df = parse_wpl_json(file_path)
            dfs_list.append(df)
        except Exception as e:
            print(f"Skipping {file_path.name} due to error: {e}")

    # 4. Concatenate everything at once
    if dfs_list:
        all_content = pd.concat(dfs_list, ignore_index=True)
        print(f"Combined {len(dfs_list)} files.")
    else:
        print("No data found.")
        all_content = pd.DataFrame()
else:
    print(f"Directory not found: {data_folder}")

# Display result
all_content.head()
# Out:
# Reading data from: d:\Projects\wpl_analysis\Data\01_raw_data\wpl_json
# Combined 22 files.
#   match_id        date  inning    batting_team                 bowling_team  \
# 0  1513682  2026-01-09       1  Mumbai Indians  Royal Challengers Bengaluru
# 1  1513682  2026-01-09       1  Mumbai Indians  Royal Challengers Bengaluru
# 2  1513682  2026-01-09       1  Mumbai Indians  Royal Challengers Bengaluru
# 3  1513682  2026-01-09       1  Mumbai Indians  Royal Challengers Bengaluru
# 4  1513682  2026-01-09       1  Mumbai Indians  Royal Challengers Bengaluru
#
#    over  ball   batter   bowler non_striker  runs_bat  runs_extras  \
# 0     0     1  AC Kerr  LK Bell  G Kamalini         0            0
# 1     0     2  AC Kerr  LK Bell  G Kamalini         0            0
# 2     0     3  AC Kerr  LK Bell  G Kamalini         0            0
# 3     0     4  AC Kerr  LK Bell  G Kamalini         0            0
# 4     0     5  AC Kerr  LK Bell  G Kamalini         0            0
#
#    runs_total  is_wide  is_noball  is_wicket player_out wicket_kind
# 0           0        0          0          0        NaN         NaN
# 1           0        0          0          0        NaN         NaN
# 2           0        0          0          0        NaN         NaN
# 3           0        0          0          0        NaN         NaN
# 4           0        0          0          0        NaN         NaN

# %%
all_content
# Out:
#      match_id        date  inning                 batting_team  \
# 0     1513682  2026-01-09       1               Mumbai Indians
# 1     1513682  2026-01-09       1               Mumbai Indians
# 2     1513682  2026-01-09       1               Mumbai Indians
# 3     1513682  2026-01-09       1               Mumbai Indians
# 4     1513682  2026-01-09       1               Mumbai Indians
# ...       ...         ...     ...                          ...
# 5245  1513703  2026-02-05       2  Royal Challengers Bengaluru
# 5246  1513703  2026-02-05       2  Royal Challengers Bengaluru
# 5247  1513703  2026-02-05       2  Royal Challengers Bengaluru
# 5248  1513703  2026-02-05       2  Royal Challengers Bengaluru
# 5249  1513703  2026-02-05       2  Royal Challengers Bengaluru
#
#                      bowling_team  over  ball      batter           bowler  \
# 0     Royal Challengers Bengaluru     0     1     AC Kerr          LK Bell
# 1     Royal Challengers Bengaluru     0     2     AC Kerr          LK Bell
# 2     Royal Challengers Bengaluru     0     3     AC Kerr          LK Bell
# 3     Royal Challengers Bengaluru     0     4     AC Kerr          LK Bell
# 4     Royal Challengers Bengaluru     0     5     AC Kerr          LK Bell
# ...                           ...   ...   ...         ...              ...
# 5245               Delhi Capitals    18     6    RP Yadav         CA Henry
# 5246               Delhi Capitals    19     1    RP Yadav  N Shree Charani
# 5247               Delhi Capitals    19     2  N de Klerk  N Shree Charani
# 5248               Delhi Capitals    19     3    RP Yadav  N Shree Charani
# 5249               Delhi Capitals    19     4    RP Yadav  N Shree Charani
#
#      non_striker  runs_bat  runs_extras  runs_total  is_wide  is_noball  \
# 0     G Kamalini         0            0           0        0          0
# 1     G Kamalini         0            0           0        0          0
# 2     G Kamalini         0            0           0        0          0
# 3     G Kamalini         0            0           0        0          0
# 4     G Kamalini         0            0           0        0          0
# ...          ...       ...          ...         ...      ...        ...
# 5245  N de Klerk         1            0           1        0          0
# 5246  N de Klerk         1            0           1        0          0
# 5247    RP Yadav         1            0           1        0          0
# 5248  N de Klerk         4            0           4        0          0
# 5249  N de Klerk         4            0           4        0          0
#
#       is_wicket player_out wicket_kind
# 0             0        NaN         NaN
# 1             0        NaN         NaN
# 2             0        NaN         NaN
# 3             0        NaN         NaN
# 4             0        NaN         NaN
# ...         ...        ...         ...
# 5245          0        NaN         NaN
# 5246          0        NaN         NaN
# 5247          0        NaN         NaN
# 5248          0        NaN         NaN
# 5249          0        NaN         NaN
#
# [5250 rows x 18 columns]

# %%
all_content[
    (all_content['is_wicket'] != 0) & (all_content['bowler'] == 'NSS Sharma')
]
# Out:
#      match_id        date  inning                 batting_team  \
# 541   1513684  2026-01-10       1               Mumbai Indians
# 615   1513684  2026-01-10       1               Mumbai Indians
# 809   1513685  2026-01-11       1               Gujarat Giants
# 862   1513685  2026-01-11       1               Gujarat Giants
# 864   1513685  2026-01-11       1               Gujarat Giants
# 865   1513685  2026-01-11       1               Gujarat Giants
# 866   1513685  2026-01-11       1               Gujarat Giants
# 1533  1513688  2026-01-14       1                  UP Warriorz
# 2640  1513692  2026-01-17       2  Royal Challengers Bengaluru
# 2919  1513694  2026-01-20       1               Mumbai Indians
# 3481  1513696  2026-01-24       1  Royal Challengers Bengaluru
# 3494  1513696  2026-01-24       1  Royal Challengers Bengaluru
# 3496  1513696  2026-01-24       1  Royal Challengers Bengaluru
# 3944  1513698  2026-01-27       1               Gujarat Giants
# 4809  1513702  2026-02-03       1               Gujarat Giants
# 4810  1513702  2026-02-03       1               Gujarat Giants
# 4903  1513702  2026-02-03       1               Gujarat Giants
# 5237  1513703  2026-02-05       2  Royal Challengers Bengaluru
#
#         bowling_team  over  ball        batter      bowler      non_striker  \
# 541   Delhi Capitals     6     3    G Kamalini  NSS Sharma  NR Sciver-Brunt
# 615   Delhi Capitals    18     3      NJ Carey  NSS Sharma           H Kaur
# 809   Delhi Capitals    10     5    SFM Devine  NSS Sharma        A Gardner
# 862   Delhi Capitals    19     2     KS Gautam  NSS Sharma         KS Ahuja
# 864   Delhi Capitals    19     4      KS Ahuja  NSS Sharma        TP Kanwar
# 865   Delhi Capitals    19     5   RS Gayakwad  NSS Sharma        TP Kanwar
# 866   Delhi Capitals    19     6  Renuka Singh  NSS Sharma        TP Kanwar
# 1533  Delhi Capitals    15     4    MM Lanning  NSS Sharma           H Deol
# 2640  Delhi Capitals    17     2    S Mandhana  NSS Sharma           G Voll
# 2919  Delhi Capitals     3     5      S Sajana  NSS Sharma      HK Matthews
# 3481  Delhi Capitals    17     3       A Reddy  NSS Sharma       N de Klerk
# 3494  Delhi Capitals    19     4      SR Patil  NSS Sharma      SG Satghare
# 3496  Delhi Capitals    19     6   SG Satghare  NSS Sharma          LK Bell
# 3944  Delhi Capitals    16     3     BL Mooney  NSS Sharma         KS Ahuja
# 4809  Delhi Capitals     5     1     AB Sharma  NSS Sharma        BL Mooney
# 4810  Delhi Capitals     5     2     A Gardner  NSS Sharma        BL Mooney
# 4903  Delhi Capitals    19     6     BL Mooney  NSS Sharma        KS Gautam
# 5237  Delhi Capitals    17     4      RM Ghosh  NSS Sharma       S Mandhana
#
#       runs_bat  runs_extras  runs_total  is_wide  is_noball  is_wicket  \
# 541          0            0           0        0          0          1
# 615          0            0           0        0          0          1
# 809          0            0           0        0          0          1
# 862          0            0           0        0          0          1
# 864          0            0           0        0          0          1
# 865          0            0           0        0          0          1
# 866          0            0           0        0          0          1
# 1533         0            0           0        0          0          1
# 2640         0            0           0        0          0          1
# 2919         0            0           0        0          0          1
# 3481         0            0           0        0          0          1
# 3494         0            0           0        0          0          1
# 3496         0            0           0        0          0          1
# 3944         0            0           0        0          0          1
# 4809         0            0           0        0          0          1
# 4810         0            0           0        0          0          1
# 4903         1            0           1        0          0          1
# 5237         0            0           0        0          0          1
#
#         player_out wicket_kind
# 541     G Kamalini      caught
# 615       NJ Carey      bowled
# 809     SFM Devine      caught
# 862      KS Gautam      caught
# 864       KS Ahuja     stumped
# 865    RS Gayakwad      bowled
# 866   Renuka Singh      bowled
# 1533    MM Lanning      caught
# 2640    S Mandhana      caught
# 2919      S Sajana      bowled
# 3481       A Reddy         lbw
# 3494      SR Patil      caught
# 3496   SG Satghare      bowled
# 3944     BL Mooney      caught
# 4809     AB Sharma      caught
# 4810     A Gardner      caught
# 4903     KS Gautam     run out
# 5237      RM Ghosh      caught

# %%
all_content.to_csv(r'D:\Projects\wpl_analysis\Data\02_cleaned_da\cleaned_data',index=False)
